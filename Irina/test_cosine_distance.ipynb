# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_distances
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

from Irina import utility_functions as uf

# %%
path = "../data/"

# %%
df_country_subfield = (
    pd.read_csv(path+"df_country_subfield_norm_world_log.csv", index_col=0)
    .dropna(how="all", axis=1)
    .fillna(0)
)

# %%
df_country_subfield
# Out:
#              1100      1102      1103      1104      1105      1106      1107  \
# country
# AD       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AE      -0.691529  0.046243 -1.051608  0.567711 -2.247748 -0.288924  0.000000
# AF       0.000000  2.687943  0.000000  0.000000  1.492564  0.000000  0.000000
# AG       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AL       0.000000  0.000000  0.000000  0.000000  0.763049  0.524648  2.224851
# ...           ...       ...       ...       ...       ...       ...       ...
# XK       0.000000  2.310649  0.000000  2.138968  0.000000  0.589187  0.000000
# YE       0.000000  1.659647  1.254943  1.082502 -0.634345  0.631332  0.000000
# ZA       0.683136  0.852924  0.873103  0.215154  1.091695  0.236589  1.119347
# ZM       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  3.514753
# ZW       0.879729  1.905183  0.000000  0.000000  0.000000  0.000000  1.883924
#
#          1108      1109      1110  ...      3603      3604      3605  \
# country                            ...
# AD        0.0  0.000000  3.113576  ...  0.000000  0.000000  0.000000
# AE        0.0  0.000000 -0.546693  ...  0.000000  0.453564  0.451423
# AF        0.0  0.000000  0.628669  ...  0.000000  2.807582  3.498588
# AG        0.0  0.000000  0.000000  ...  0.000000  0.000000  4.309518
# AL        0.0  0.000000 -0.506311  ...  0.000000  1.672602  0.000000
# ...       ...       ...       ...  ...       ...       ...       ...
# XK        0.0  0.000000  0.656840  ...  0.000000  0.000000  0.000000
# YE        0.0  0.363428  0.804346  ...  0.000000  0.000000  0.000000
# ZA        0.0  0.913147  0.531706  ...  0.934918  0.336574 -0.188815
# ZM        0.0  0.000000  0.378126  ...  0.000000  0.000000  0.000000
# ZW        0.0  0.321283  0.405525  ...  0.000000  0.000000  0.000000
#
#              3607  3608      3609      3611      3612      3614      3616
# country
# AD       0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# AE       0.000000   0.0  0.000000  0.569795  0.000000  0.000000  0.253751
# AF       0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# AG       0.000000   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# AL       0.000000   0.0  0.000000  0.000000  1.677328  0.000000  0.000000
# ...           ...   ...       ...       ...       ...       ...       ...
# XK       0.000000   0.0  0.000000  2.546518  0.000000  2.497200  0.000000
# YE       0.000000   0.0  0.000000  0.000000  0.000000  1.440734  0.000000
# ZA      -0.538278   0.0  0.765286  0.622704 -2.261389  0.439855  0.099021
# ZM       0.000000   0.0  0.000000  0.000000  0.000000  1.930805  1.664079
# ZW       0.000000   0.0  0.000000  0.000000  0.000000  0.000000  1.131862
#
# [220 rows x 252 columns]

# %%
D = cosine_distances(df_country_subfield.values)

df_country_dist_cosine = pd.DataFrame(D,
                                     index=df_country_subfield.index,
                                     columns=df_country_subfield.index)

# df_country_dist_cosine.to_csv(path+"df_country_dist_cosine_world_log.csv")
# Out:
# /Users/irinavorobeva/PycharmProjects/geoscience/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/irinavorobeva/PycharmProjects/geoscience/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/irinavorobeva/PycharmProjects/geoscience/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
df_country_dist_cosine
# Out:
# country        AD        AE        AF        AG        AL        AM        AO  \
# country
# AD       0.000000  1.010035  0.970367  1.000000  1.045077  1.071946  0.951185
# AE       1.010035  0.000000  0.993837  1.033103  0.916297  1.061037  0.978482
# AF       0.970367  0.993837  0.000000  0.816524  0.881103  1.002821  0.871123
# AG       1.000000  1.033103  0.816524  0.000000  0.797182  0.981166  0.914720
# AL       1.045077  0.916297  0.881103  0.797182  0.000000  0.962571  0.979562
# ...           ...       ...       ...       ...       ...       ...       ...
# XK       0.971496  1.027197  0.914620  0.967109  0.814669  0.884654  0.863744
# YE       0.927736  0.823164  0.913633  0.928481  0.877412  0.794796  0.965609
# ZA       0.994518  0.938412  0.993739  1.093340  1.095599  0.991359  0.891479
# ZM       0.948058  0.919861  0.761010  0.924380  0.822925  1.004277  0.841413
# ZW       0.972629  0.902384  0.875148  0.962358  0.835823  1.001891  0.748054
#
# country        AR        AS        AT  ...        VG        VI        VN  \
# country                                ...
# AD       0.953860  1.000000  1.020633  ...  1.000000  1.000000  1.007659
# AE       1.201976  1.037087  1.084257  ...  0.952641  1.045559  0.855534
# AF       1.117433  0.936276  0.973096  ...  0.981394  0.878885  0.952923
# AG       1.108137  1.000000  0.887677  ...  1.034716  1.000000  1.057031
# AL       1.049321  0.969899  0.918591  ...  1.010776  0.875828  1.056664
# ...           ...       ...       ...  ...       ...       ...       ...
# XK       1.069309  0.877227  1.085814  ...  0.877248  0.936944  1.007437
# YE       1.012825  0.972012  1.113755  ...  0.926484  1.002084  0.878544
# ZA       0.687256  0.995617  1.166453  ...  0.975606  0.914041  0.920979
# ZM       0.962136  0.940992  1.092245  ...  0.917555  0.874457  0.959103
# ZW       0.838812  0.950887  1.194130  ...  0.956422  0.879294  0.913433
#
# country        VU        WS        XK        YE        ZA        ZM        ZW
# country
# AD       0.897467  0.804632  0.971496  0.927736  0.994518  0.948058  0.972629
# AE       1.125427  1.073693  1.027197  0.823164  0.938412  0.919861  0.902384
# AF       0.838524  0.890914  0.914620  0.913633  0.993739  0.761010  0.875148
# AG       0.972663  1.000000  0.967109  0.928481  1.093340  0.924380  0.962358
# AL       0.995675  0.984792  0.814669  0.877412  1.095599  0.822925  0.835823
# ...           ...       ...       ...       ...       ...       ...       ...
# XK       0.849059  0.944371  0.000000  0.736364  1.092326  0.865815  0.873434
# YE       0.929526  0.970795  0.736364  0.000000  0.890031  0.773641  0.655426
# ZA       0.958160  0.951496  1.092326  0.890031  0.000000  0.782935  0.706522
# ZM       0.819399  0.940877  0.865815  0.773641  0.782935  0.000000  0.477650
# ZW       0.852292  0.986487  0.873434  0.655426  0.706522  0.477650  0.000000
#
# [220 rows x 220 columns]

# %%
uf.plotly_heatmap(
    # df_country_dist_cosine,
    # y_labels=df_country_dist_cosine.index.astype(str).to_list(),
    # x_labels=df_country_dist_cosine.columns.astype(str).to_list(),
    df_country_dist_cosine.loc[uf.top_n_countries_by_articles(30), uf.top_n_countries_by_articles(30)],
    y_labels=uf.top_n_countries_by_articles(30),
    x_labels=uf.top_n_countries_by_articles(30),
    y_type="country",
    x_type="country",
    y_name="X-Country",
    x_name="Y-Country",
    title="Cosine distance",
    line_height=30,
    z_min=0, z_max=2
)

# %%
import numpy as np
import plotly.graph_objects as go

country_list = ["US", "CN", "GB"]  # list of countries
x = df_country_subfield.columns.to_list()

fig = go.Figure()

for country in country_list:
    y = df_country_subfield.loc[country].values
    y_safe = [v if not np.isnan(v) else None for v in y]  # handle NaNs

    fig.add_trace(go.Scatter(
        x=x,
        y=y_safe,
        mode="lines",
        name=f"{uf.id2name_country[country]}"
    ))

fig.update_layout(
    title="Interest distributions for selected countries",
    xaxis=dict(title="Sub-field"),
    yaxis=dict(title="Sub-field share"),
    legend=dict(x=0.01, y=0.99),
    margin=dict(l=60, r=60, t=40, b=40)
)

fig.show()
