# %%
import numpy as np
import pyarrow.parquet as pq

import plotly.graph_objects as go
import matplotlib.pyplot as plt

from irina import utility_functions as uf

# %% [markdown]
# # Upload data
#
# We are now working solely with 2010 data

# %%
path = "../data/"

# %%
parqToRead=path+'authorsPapersTopicsYearInstitutions.parquet'
# Read the parquet file filtering the lines where year=2005
table = pq.read_table(parqToRead, filters=[('year','=','2010')])
#table = pq.read_table(parqToRead)
# Convert to pandas DataFrame
df = table.to_pandas()

# %%
df.head()
# Out:
#          authors           id  year  institution country  \
# 83   A5104829885  W4400863937  2010   I189238007      UA
# 84   A5010153016  W4400863937  2010   I189238007      UA
# 85   A5061654139  W4400863937  2010   I189238007      UA
# 820  A5052243613  W2112665120  2010  I4210134612      GB
# 821  A5072218476  W2112665120  2010  I4210134612      GB
#
#                     coord                                     inst_name  \
# 83    [50.45466, 30.5238]  Taras Shevchenko National University of Kyiv
# 84    [50.45466, 30.5238]  Taras Shevchenko National University of Kyiv
# 85    [50.45466, 30.5238]  Taras Shevchenko National University of Kyiv
# 820  [51.1891, -0.890375]                               Forest Research
# 821  [51.1891, -0.890375]                               Forest Research
#
#       topic
# 83   T12618
# 84   T12618
# 85   T12618
# 820  T12618
# 821  T12618

# %% [markdown]
# # Aggregate by subfield

# %%
df_author_subfield = (
    df
    .merge(uf.df_topics[["topic_id", "subfield_id"]], left_on="topic", right_on="topic_id", how="left")
    .drop(["topic_id"], axis=1)
)

# %%
df_country_subfield = (
    df_author_subfield
    [["id", "country", "subfield_id"]]
    .drop_duplicates()
    .groupby(["country", "subfield_id"], as_index=False)
    .count()
    .pivot(index="country", columns="subfield_id", values="id")
)
mx_country_subfield = np.matrix(df_country_subfield.values)
df_country_subfield
# Out:
# subfield_id  1100  1102  1103  1104   1105  1106  1107  1108  1109   1110  \
# country
# AD            NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN    1.0
# AE            1.0   3.0   1.0   3.0    1.0   6.0   NaN   NaN   NaN   13.0
# AF            NaN   1.0   NaN   NaN    1.0   NaN   NaN   NaN   NaN    1.0
# AG            NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN    NaN
# AL            NaN   NaN   NaN   NaN    3.0   2.0   1.0   NaN   NaN    2.0
# ...           ...   ...   ...   ...    ...   ...   ...   ...   ...    ...
# XK            NaN   2.0   NaN   1.0    NaN   1.0   NaN   NaN   NaN    3.0
# YE            NaN   3.0   2.0   1.0    1.0   3.0   NaN   NaN   1.0   10.0
# ZA           30.0  51.0  52.0  16.0  214.0  77.0  17.0   NaN  66.0  290.0
# ZM            NaN   NaN   NaN   NaN    NaN   NaN   3.0   NaN   NaN    4.0
# ZW            1.0   4.0   NaN   NaN    NaN   NaN   1.0   NaN   1.0    7.0
#
# ...

# %%
df_country_subfield_authors = (
    df_author_subfield
    [["id", "country", "subfield_id"]]
    # .drop_duplicates()
    .groupby(["country", "subfield_id"], as_index=False)
    .count()
    .pivot(index="country", columns="subfield_id", values="id")
)

# %%
# df_country_subfield.to_csv(path+"df_country_subfield.csv")
# df_country_subfield_authors.to_csv(path+"df_country_subfield_authors.csv")

# %%
# top-20 active countries
df_articles_by_country = (
    df_country_subfield
    .sum(axis=1)
    .to_frame(name='total_articles')
    .assign(log_total_articles=lambda df: np.log(df.total_articles))
)
top_20_countries_list = df_articles_by_country.sort_values("total_articles", ascending=False).head(20).index.tolist()
(
    df_articles_by_country
    .sort_values("total_articles", ascending=False)
    .head(10)
)
# Out:
#          total_articles  log_total_articles
# country
# US             590234.0           13.288274
# CN             566541.0           13.247305
# GB             156317.0           11.959641
# DE             134641.0           11.810367
# FR             121503.0           11.707694
# JP             113323.0           11.637997
# CA              82397.0           11.319304
# ES              66113.0           11.099121
# IT              65472.0           11.089378
# BR              64944.0           11.081281

# %%
# top-10 active subfields (in the world)
df_subfield_representation_world = (
    df_country_subfield
    .sum(axis=0)
    .to_frame(name='total_articles')
    .assign(total_share=lambda df: df.total_articles / df.total_articles.sum())
)
(
    df_subfield_representation_world
    .sort_values("total_articles", ascending=False)
    .merge(uf.df_topics[["subfield_id", "subfield_name"]].drop_duplicates(), left_index=True, right_on="subfield_id", how="left")
    .head(10)
)
# Out:
#      total_articles  total_share  subfield_id  \
# 17         119098.0     0.042790         2208
# 14         111396.0     0.040023         1312
# 54          80676.0     0.028985         3312
# 73          67400.0     0.024216         2505
# 19          62314.0     0.022388         1702
# 39          55636.0     0.019989         2207
# 188         54466.0     0.019569         2746
# 58          53857.0     0.019350         2204
# 79          51858.0     0.018632         1705
# 187         47028.0     0.016896         2210
#
#                              subfield_name
# 17   Electrical and Electronic Engineering
# 14                       Molecular Biology
# 54         Sociology and Political Science
# 73                     Materials Chemistry
# 19                 Artificial Intelligence
# 39         Control and Systems Engineering
# 188                                Surgery
# 58                  Biomedical Engineering
# 79    Computer Networks and Communications
# ...

# %%
df_country_subfield_norm = (
    df_country_subfield
    .div(df_country_subfield.sum(axis=1), axis=0)
)
df_country_subfield_norm
# Out:
# subfield_id      1100      1102      1103      1104      1105      1106  \
# country
# AD                NaN       NaN       NaN       NaN       NaN       NaN
# AE           0.000660  0.001979  0.000660  0.001979  0.000660  0.003958
# AF                NaN  0.027778       NaN       NaN  0.027778       NaN
# AG                NaN       NaN       NaN       NaN       NaN       NaN
# AL                NaN       NaN       NaN       NaN  0.013393  0.008929
# ...               ...       ...       ...       ...       ...       ...
# XK                NaN  0.019048       NaN  0.009524       NaN  0.009524
# YE                NaN  0.009934  0.006623  0.003311  0.003311  0.009934
# ZA           0.002608  0.004434  0.004521  0.001391  0.018604  0.006694
# ZM                NaN       NaN       NaN       NaN       NaN       NaN
# ZW           0.003175  0.012698       NaN       NaN       NaN       NaN
#
# subfield_id      1107  1108      1109      1110  ...      3603      3604  \
# ...

# %%
df_country_subfield_norm_world = (
    df_country_subfield_norm
    .div(df_subfield_representation_world.total_share)
)
df_country_subfield_norm_world_norm = (
    df_country_subfield_norm_world
    .div(df_country_subfield_norm_world.sum(axis=1), axis=0)
)
df_country_subfield_norm_world_norm
# Out:
# subfield_id      1100      1102      1103      1104      1105      1106  \
# country
# AD                NaN       NaN       NaN       NaN       NaN       NaN
# AE           0.002041  0.004267  0.001424  0.007188  0.000430  0.003052
# AF                NaN  0.051835       NaN       NaN  0.015685       NaN
# AG                NaN       NaN       NaN       NaN       NaN       NaN
# AL                NaN       NaN       NaN       NaN  0.009078  0.007153
# ...               ...       ...       ...       ...       ...       ...
# XK                NaN  0.032253       NaN  0.027165       NaN  0.005767
# YE                NaN  0.017513  0.011684  0.009834  0.001766  0.006263
# ZA           0.006312  0.007480  0.007633  0.003953  0.009498  0.004039
# ZM                NaN       NaN       NaN       NaN       NaN       NaN
# ZW           0.008344  0.023266       NaN       NaN       NaN       NaN
#
# subfield_id      1107  1108      1109      1110  ...     3603      3604  \
# ...

# %%
df_subfield_country_norm = (
    df_country_subfield
    .T
    .div(df_country_subfield.T.sum(axis=1), axis=0)
)
df_subfield_country_norm
# Out:
# country      AD        AE        AF  AG        AL        AM        AO  \
# subfield_id
# 1100        NaN  0.000273       NaN NaN       NaN       NaN  0.000818
# 1102        NaN  0.000570  0.000190 NaN       NaN  0.000190       NaN
# 1103        NaN  0.000190       NaN NaN       NaN       NaN       NaN
# 1104        NaN  0.000961       NaN NaN       NaN       NaN       NaN
# 1105        NaN  0.000058  0.000058 NaN  0.000173  0.000288       NaN
# ...          ..       ...       ...  ..       ...       ...       ...
# 3609        NaN       NaN       NaN NaN       NaN       NaN       NaN
# 3611        NaN  0.000963       NaN NaN       NaN       NaN       NaN
# 3612        NaN       NaN       NaN NaN  0.000431       NaN       NaN
# 3614        NaN       NaN       NaN NaN       NaN       NaN       NaN
# 3616        NaN  0.000702       NaN NaN       NaN  0.000351  0.000351
#
# country            AR  AS        AT  ...       VG        VI        VN  VU  \
# ...

# %%
x_labels = list(map(str, df_country_subfield_norm_world.columns))
y_labels = list(map(str, top_20_countries_list))

fig = go.Figure(
    data=go.Heatmap(
        z=df_subfield_country_norm.T.loc[top_20_countries_list].values,
        x=x_labels,
        y=y_labels,
        colorscale="Viridis",
        zmin=0,
        zmax=1,
    )
)

# Layout
fig.update_layout(
    title="Representation vs The world",
    width=1000,
    height=30*len(y_labels),  # taller if more rows
    margin=dict(l=100, r=50, t=50, b=100),
    xaxis=dict(tickangle=45, automargin=True),
    yaxis=dict(autorange="reversed", automargin=True)  # keep top-to-bottom ordering
)

fig.show()

# %%
x_labels = list(map(str, df_country_subfield_norm_world.columns))
y_labels = list(map(str, top_20_countries_list))

fig = go.Figure(
    data=go.Heatmap(
        z=df_country_subfield_norm.loc[top_20_countries_list].values,
        x=x_labels,
        y=y_labels,
        colorscale="Viridis",
        zmin=0,
        zmax=0.05,
    )
)

# Layout
fig.update_layout(
    title="Sub-field Representation (share in all country's articles)",
    width=1000,
    height=30*len(y_labels),  # taller if more rows
    margin=dict(l=100, r=50, t=50, b=100),
    xaxis=dict(tickangle=45, automargin=True),
    yaxis=dict(autorange="reversed", automargin=True)  # keep top-to-bottom ordering
)

fig.show()

# %%
x_labels = list(map(str, df_country_subfield_norm_world.columns))
y_labels = list(map(str, top_20_countries_list))

fig = go.Figure(
    data=go.Heatmap(
        z=df_country_subfield_norm_world.loc[top_20_countries_list].values,
        x=x_labels,
        y=y_labels,
        colorscale="Viridis",
        zmin=0,
        zmax=2,
    )
)

# Layout
fig.update_layout(
    title="Representation vs The world (bigger than 1 - more represented than average around in the world)",
    width=1000,
    height=30*len(y_labels),  # taller if more rows
    margin=dict(l=100, r=50, t=50, b=100),
    xaxis=dict(tickangle=45, automargin=True),
    yaxis=dict(autorange="reversed", automargin=True)  # keep top-to-bottom ordering
)

fig.show()

# %%
x_labels = list(map(str, df_country_subfield_norm_world.columns))
y_labels = list(map(str, top_20_countries_list))

fig = go.Figure(
    data=go.Heatmap(
        z=df_country_subfield_norm_world_norm.loc[top_20_countries_list].values,
        x=x_labels,
        y=y_labels,
        colorscale="Viridis",
        zmin=0,
        zmax=0.01,
    )
)

# Layout
fig.update_layout(
    title="Representation vs The world (normalised by country)",
    width=1000,
    height=30*len(y_labels),  # taller if more rows
    margin=dict(l=100, r=50, t=50, b=100),
    xaxis=dict(tickangle=45, automargin=True),
    yaxis=dict(autorange="reversed", automargin=True)  # keep top-to-bottom ordering
)

fig.show()

# %%
uf.get_subfield_info(2505)
# Out:
#     subfield_id        subfield_name         field_name        domain_name
# 73         2505  Materials Chemistry  Materials Science  Physical Sciences

# %%
uf.get_country_info("AX")
# Out:
#             name  region       sub-region code
# 1  Åland Islands  Europe  Northern Europe   AX
