# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sigma1 = 1
sigma2 = 2
corr = 0.5
cov = np.array([[sigma1**2, sigma1 * sigma2 * corr], [sigma1 * sigma2 * corr, sigma2**2]])
cov
# Out:
# array([[1., 1.],
#        [1., 4.]])

# %%
vals, vec = np.linalg.eig(cov)

# %%
v11 = vec[0, 0]
v12 = vec[1, 0]
v21 =
v22 =

# %%
sample = np.random.multivariate_normal([0, 0], cov, size=1000)
plt.scatter(sample[:, 0], sample[:, 1])
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.plot([0, vals[0] * vec[0, 0]], [0, vals[0] * vec[1, 0]], color="red")
plt.plot([0, vals[1] * vec[0, 1]], [0, vals[1] * vec[1, 1]], color="red")
plt.axhline(0, c="grey", alpha=0.5)
plt.axvline(0, c="grey", alpha=0.5)

# %%
pd.DataFrame(sample).corr()
# Out:
#          0        1
# 0  1.00000  0.52196
# 1  0.52196  1.00000
